# %% [markdown]
# # Graph Theory Measure on Connectomes from CUBRIC Neuroimaging Data

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt

# %%
features_path = '/workspaces/profCode/bctWrapper/schaefer_features'
measure_list_path = '/workspaces/profCode/bctWrapper/src/schaefer/featureList.txt'
scanner_protocols = ('connectomeSa', 'connectomeSt', 'prismaSa', 'prismaSt')

measure_list = open(measure_list_path,'r').read().split('\n')

# %% [markdown]
# ## Utilities functions

# %%
def read_measure_output_file(measure_name):
    data = []
    for protocol in scanner_protocols:
        measure_path = os.path.join(features_path, protocol, measure_name + '.txt')
        arr = np.loadtxt(measure_path)
        if (len(arr.shape) > 1):
            arr = np.average(arr, axis=1)
        data.append(arr)
    return data

# %%
def drawBoxPlot(data, title):
    fig, ax = plt.subplots()
    ax.boxplot(data)
    plt.xticks([1, 2, 3, 4], ["Connectome SA", "Connectome ST", "Prisma SA", "Prisma ST"])
    plt.title(title)
    plt.show()

# %% [markdown]
# ## Load measure output files and Visualize Box Plot

# %%
for measure in measure_list:
    try: 
        data = read_measure_output_file(measure)
    except FileNotFoundError as e:
        print(f'File {measure}.txt not found')
    except ValueError as e:
        print(f'{e}')
    drawBoxPlot(data, measure)
# Out:
# File node_betweenness_centrality.txt not found
# File local_efficiency.txt not found
# File eccentricity.txt not found
# File local_assortativity.txt not found
# File ####Global Measures.txt not found
# File node_betweenness_centrality_avg.txt not found
# File eccentricity_avg.txt not found
# File small_worldness.txt not found
# File characteristic_path_length.txt not found
# File global_efficiency.txt not found
# File radius.txt not found
# File diameter.txt not found
# File .txt not found
